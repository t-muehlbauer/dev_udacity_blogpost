# %% [markdown]
# # Impact of the COVID-19 pandemic on German society between 2019 and 2021.

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Imports

# %%
# Importing libraries to handle data
import numpy as np
import pandas as pd

# Importing libraries to plot data
import matplotlib.pyplot as plt

import csv

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Relevant data

# %%
# Reading in ALLBUS survey data from 2018 and 2021
df_2018_raw = pd.io.stata.read_stata('data/ZA5217_ALLBUS_2018/ZA5270_v2-0-0.dta', convert_categoricals=False)
df_2021_raw = pd.io.stata.read_stata('data/ZA5280_ALLBUS_2021/ZA5280_v2-0-0.dta', convert_categoricals=False)

# Converting the data to .csv
df_2018_csv = df_2018_raw.to_csv('data/ZA5217_ALLBUS_2018/ZA5270_v2-0-0.csv')
df_2021_csv = df_2021_raw.to_csv('data/ZA5280_ALLBUS_2021/ZA5280_v2-0-0.csv')

# Reading in the .csv file
df_2018 = pd.read_csv('data/ZA5217_ALLBUS_2018/ZA5270_v2-0-0.csv')
df_2021 = pd.read_csv('data/ZA5280_ALLBUS_2021/ZA5280_v2-0-0.csv')

# Show the dimension of the datasets
print("Dimension of 2018: " + str(df_2018.shape))
print("Dimension of 2021: " + str(df_2021.shape))
# Out:
# Dimension of 2018: (3477, 709)
# Dimension of 2021: (5342, 545)

# %%
# Head of 2018
df_2018.head()
# Out:
#    Unnamed: 0  za_nr                  doi             version  respid  \
# 0           0   5270  doi:10.4232/1.13250  2.0.0 (2019-03-26)       1
# 1           1   5270  doi:10.4232/1.13250  2.0.0 (2019-03-26)       2
# 2           2   5270  doi:10.4232/1.13250  2.0.0 (2019-03-26)       3
# 3           3   5270  doi:10.4232/1.13250  2.0.0 (2019-03-26)       4
# 4           4   5270  doi:10.4232/1.13250  2.0.0 (2019-03-26)       5
#
#    eastwest  german  ep01  ep03  ep04  ...  xi04  xi05  land  bik  gkpol  \
# 0         1       1     1     2     2  ...     3     9    90    4      1
# 1         2       1     2     4     3  ...     1     3   150    8      6
# 2         1       1     2     2     3  ...     5    27    30    9      4
# 3         2       1     2     2     3  ...     5    11   120    9      2
# 4         2       1     3     2     3  ...     5    12   140   10      7
#
#    xs11   wghtpew    wghtht   wghthew  wghthtew
# 0     2  1.207859  0.870885  1.198172  1.043471
# 1    69  0.544808  0.829881  0.566418  0.470059
# 2   138  1.207859  0.870885  1.198172  1.043471
# 3    74  0.544808  0.829881  0.566418  0.470059
# 4    42  0.544808  0.829881  0.566418  0.470059
#
# [5 rows x 709 columns]

# %%
# Head of 2021
df_2021.head()
# Out:
#    Unnamed: 0  za_nr                              doi             version  \
# 0           0   5280  https://doi.org/10.4232/1.14002  2.0.0 (2022-09-26)
# 1           1   5280  https://doi.org/10.4232/1.14002  2.0.0 (2022-09-26)
# 2           2   5280  https://doi.org/10.4232/1.14002  2.0.0 (2022-09-26)
# 3           3   5280  https://doi.org/10.4232/1.14002  2.0.0 (2022-09-26)
# 4           4   5280  https://doi.org/10.4232/1.14002  2.0.0 (2022-09-26)
#
#    respid  substudy  mode  splt21  eastwest  german  ...  xt10c  xs15  xs16  \
# 0       1         1     4       2         1       1  ...      1     1     2
# 1       2         1     4       1         1       1  ...      3     1     1
# 2       3         1     4       1         1       1  ...      4     1     1
# 3       4         1     4       2         2       1  ...      5     1     1
# 4       5         1     4       2         1       1  ...      3     1     1
#
#    land  bik  gkpol   wghtpew    wghtht   wghthew  wghthtew
# 0    80    3      3  1.247175  1.685751  1.235898  2.083416
# 1    50    3      3  1.247175  1.685751  1.235898  2.083416
# 2    10    4      3  1.247175  1.685751  1.235898  2.083416
# 3   160    2      2  0.506620  0.801962  0.529570  0.424695
# 4    50    7      3  1.247175  0.561917  1.235898  0.694472
#
# [5 rows x 545 columns]

# %%
# Datatypes and count of 2018 
print("Datatypes of 2018:")
df_2018.dtypes.value_counts()
# Out:
# Datatypes of 2018:
# int64      682
# float64     25
# object       2
# Name: count, dtype: int64

# %%
# Datatypes and count of 2021
print("Datatypes of 2021:")
df_2021.dtypes.value_counts()
# Out:
# Datatypes of 2021:
# int64      518
# float64     25
# object       2
# Name: count, dtype: int64
